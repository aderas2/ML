# %% [markdown]
#  LOOKING AT OUR TRAINING DATASET

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
test = pd.read_csv('Clean_Training.csv')
df_test = pd.DataFrame(test, columns = ['TransactionId','BatchId','AccountId','SubscriptionId','CustomerId','CurrencyCode'
                                    ,'CountryCode','ProviderId','ProductId','ProductCategory','ChannelId','Amount','Value',
                                   'Date','Time','PricingStrategy','FraudResult'])

# %%
print(test)
# Out:
#               TransactionId         BatchId       AccountId  \
# 0       TransactionId_76871   BatchId_36123  AccountId_3957
# 1       TransactionId_73770   BatchId_15642  AccountId_4841
# 2       TransactionId_26203   BatchId_53941  AccountId_4229
# 3         TransactionId_380  BatchId_102363   AccountId_648
# 4       TransactionId_28195   BatchId_38780  AccountId_4841
# 5       TransactionId_23223   BatchId_25954  AccountId_1078
# 6      TransactionId_118063  BatchId_118460  AccountId_2442
# 7      TransactionId_100640   BatchId_38561  AccountId_4841
# 8       TransactionId_51905   BatchId_93774   AccountId_272
# 9      TransactionId_130161   BatchId_82409   AccountId_710
# 10      TransactionId_51800  BatchId_112288  AccountId_2634
# 11      TransactionId_33857  BatchId_126394  AccountId_4841
# 12      TransactionId_94963  BatchId_104726   AccountId_710
# 13     TransactionId_104687   BatchId_59433   AccountId_710
# 14      TransactionId_86903   BatchId_59433   AccountId_710
# 15     TransactionId_118831   BatchId_59433   AccountId_710
# 16     TransactionId_122975   BatchId_31312  AccountId_2685
# 17      TransactionId_98367    BatchId_6789  AccountId_2685
# 18      TransactionId_64044  BatchId_117733  AccountId_4841
# 19     TransactionId_119821   BatchId_89644  AccountId_3081
# 20      TransactionId_94363   BatchId_94932  AccountId_4841
# 21      TransactionId_93543  BatchId_103527  AccountId_3081
# 22     TransactionId_138139    BatchId_8334  AccountId_4841
# 23      TransactionId_79885   BatchId_48769  AccountId_1825
# 24     TransactionId_127132   BatchId_50160  AccountId_2314
# 25      TransactionId_74649  BatchId_100266  AccountId_4841
# 26       TransactionId_7396  BatchId_124231  AccountId_1825
# 27     TransactionId_126754   BatchId_60208  AccountId_1616
# 28     TransactionId_136360   BatchId_48611  AccountId_4841
# 29      TransactionId_89705   BatchId_16332  AccountId_3455
# ...                     ...             ...             ...
# 95632   TransactionId_70563    BatchId_2831   AccountId_537
# 95633   TransactionId_66516   BatchId_98969  AccountId_3014
# 95634    TransactionId_5394  BatchId_121783  AccountId_2965
# 95635   TransactionId_11513   BatchId_25909  AccountId_2585
# 95636  TransactionId_112982  BatchId_108518  AccountId_4841
# 95637   TransactionId_53307  BatchId_136096  AccountId_4841
# 95638   TransactionId_20690   BatchId_18591  AccountId_1232
# 95639   TransactionId_73868   BatchId_94787  AccountId_4326
# 95640  TransactionId_131580   BatchId_16209  AccountId_1219
# 95641  TransactionId_134543   BatchId_88196  AccountId_4326
# 95642  TransactionId_117975   BatchId_55755  AccountId_4841
# 95643  TransactionId_114220   BatchId_89378  AccountId_1318
# 95644   TransactionId_49819  BatchId_127156  AccountId_3447
# 95645  TransactionId_131922   BatchId_69178  AccountId_1726
# 95646  TransactionId_128602   BatchId_88013  AccountId_4841
# 95647   TransactionId_74925   BatchId_29059  AccountId_4841
# 95648   TransactionId_96153   BatchId_24311  AccountId_1685
# 95649  TransactionId_138376  BatchId_107100   AccountId_215
# 95650   TransactionId_36354   BatchId_81234   AccountId_215
# 95651   TransactionId_16042   BatchId_49303   AccountId_215
# 95652   TransactionId_71994   BatchId_66957   AccountId_620
# 95653   TransactionId_68851  BatchId_100900  AccountId_4841
# 95654   TransactionId_18130   BatchId_20310   AccountId_620
# 95655   TransactionId_38907   BatchId_92168  AccountId_4841
# 95656   TransactionId_68402   BatchId_17092  AccountId_2659
# 95657   TransactionId_89881   BatchId_96668  AccountId_4841
# 95658   TransactionId_91597    BatchId_3503  AccountId_3439
# 95659   TransactionId_82501  BatchId_118602  AccountId_4841
# 95660  TransactionId_136354   BatchId_70924  AccountId_1346
# 95661   TransactionId_35670   BatchId_29317  AccountId_4841
#
#             SubscriptionId       CustomerId CurrencyCode  CountryCode  \
# 0       SubscriptionId_887  CustomerId_4406          UGX          256
# 1      SubscriptionId_3829  CustomerId_4406          UGX          256
# 2       SubscriptionId_222  CustomerId_4683          UGX          256
# 3      SubscriptionId_2185   CustomerId_988          UGX          256
# 4      SubscriptionId_3829   CustomerId_988          UGX          256
# 5      SubscriptionId_4238  CustomerId_1432          UGX          256
# 6      SubscriptionId_1980  CustomerId_2858          UGX          256
# 7      SubscriptionId_3829  CustomerId_2858          UGX          256
# 8      SubscriptionId_4731   CustomerId_598          UGX          256
# 9       SubscriptionId_920  CustomerId_1053          UGX          256
# 10     SubscriptionId_3511  CustomerId_3052          UGX          256
# 11     SubscriptionId_3829  CustomerId_3052          UGX          256
# 12      SubscriptionId_920  CustomerId_1053          UGX          256
# 13      SubscriptionId_920  CustomerId_1053          UGX          256
# 14      SubscriptionId_920  CustomerId_1053          UGX          256
# 15      SubscriptionId_920  CustomerId_1053          UGX          256
# 16     SubscriptionId_4626  CustomerId_3105          UGX          256
# 17     SubscriptionId_4626  CustomerId_3105          UGX          256
# 18     SubscriptionId_3829  CustomerId_3105          UGX          256
# 19     SubscriptionId_4312  CustomerId_3507          UGX          256
# 20     SubscriptionId_3829  CustomerId_3507          UGX          256
# 21     SubscriptionId_4312  CustomerId_3507          UGX          256
# 22     SubscriptionId_3829  CustomerId_3507          UGX          256
# 23     SubscriptionId_4080  CustomerId_2216          UGX          256
# 24     SubscriptionId_4722  CustomerId_2728          UGX          256
# 25     SubscriptionId_3829  CustomerId_2728          UGX          256
# 26     SubscriptionId_4080  CustomerId_2216          UGX          256
# 27     SubscriptionId_4410  CustomerId_1995          UGX          256
# 28     SubscriptionId_3829  CustomerId_1995          UGX          256
# 29      SubscriptionId_946  CustomerId_3890          UGX          256
# ...                    ...              ...          ...          ...
# 95632  SubscriptionId_3794   CustomerId_872          UGX          256
# 95633  SubscriptionId_1575  CustomerId_3439          UGX          256
# 95634  SubscriptionId_4144  CustomerId_3390          UGX          256
# 95635  SubscriptionId_2843  CustomerId_3002          UGX          256
# 95636  SubscriptionId_3829  CustomerId_3390          UGX          256
# 95637  SubscriptionId_3829  CustomerId_3002          UGX          256
# 95638  SubscriptionId_1780  CustomerId_1593          UGX          256
# 95639  SubscriptionId_2193  CustomerId_4782          UGX          256
# 95640  SubscriptionId_4187  CustomerId_1579          UGX          256
# 95641  SubscriptionId_2193  CustomerId_4782          UGX          256
# 95642  SubscriptionId_3829  CustomerId_4782          UGX          256
# 95643  SubscriptionId_1104  CustomerId_1681          UGX          256
# 95644  SubscriptionId_4352  CustomerId_3882          UGX          256
# 95645  SubscriptionId_3565  CustomerId_2111          UGX          256
# 95646  SubscriptionId_3829  CustomerId_3882          UGX          256
# 95647  SubscriptionId_3829  CustomerId_2111          UGX          256
# 95648    SubscriptionId_84  CustomerId_2067          UGX          256
# 95649   SubscriptionId_137   CustomerId_539          UGX          256
# 95650   SubscriptionId_137   CustomerId_539          UGX          256
# 95651   SubscriptionId_137   CustomerId_539          UGX          256
# 95652  SubscriptionId_1833   CustomerId_960          UGX          256
# 95653  SubscriptionId_3829   CustomerId_539          UGX          256
# 95654  SubscriptionId_1833   CustomerId_960          UGX          256
# 95655  SubscriptionId_3829   CustomerId_960          UGX          256
# 95656  SubscriptionId_3327  CustomerId_3078          UGX          256
# 95657  SubscriptionId_3829  CustomerId_3078          UGX          256
# 95658  SubscriptionId_2643  CustomerId_3874          UGX          256
# 95659  SubscriptionId_3829  CustomerId_3874          UGX          256
# 95660   SubscriptionId_652  CustomerId_1709          UGX          256
# 95661  SubscriptionId_3829  CustomerId_1709          UGX          256
#
#          ProviderId     ProductId     ProductCategory    ChannelId   Amount  \
# 0      ProviderId_6  ProductId_10             airtime  ChannelId_3   1000.0
# 1      ProviderId_4   ProductId_6  financial_services  ChannelId_2    -20.0
# 2      ProviderId_6   ProductId_1             airtime  ChannelId_3    500.0
# 3      ProviderId_1  ProductId_21        utility_bill  ChannelId_3  20000.0
# 4      ProviderId_4   ProductId_6  financial_services  ChannelId_2   -644.0
# 5      ProviderId_6   ProductId_3             airtime  ChannelId_3   2000.0
# 6      ProviderId_5   ProductId_3             airtime  ChannelId_3  10000.0
# 7      ProviderId_4   ProductId_6  financial_services  ChannelId_2   -500.0
# 8      ProviderId_6  ProductId_10             airtime  ChannelId_3    500.0
# 9      ProviderId_1  ProductId_15  financial_services  ChannelId_3    600.0
# 10     ProviderId_6   ProductId_3             airtime  ChannelId_3    890.0
# 11     ProviderId_4   ProductId_6  financial_services  ChannelId_2    -40.0
# 12     ProviderId_1  ProductId_15  financial_services  ChannelId_3    600.0
# 13     ProviderId_3  ProductId_15  financial_services  ChannelId_3   4000.0
# 14     ProviderId_3  ProductId_15  financial_services  ChannelId_3   4000.0
# 15     ProviderId_3  ProductId_15  financial_services  ChannelId_3   4000.0
# 16     ProviderId_5  ProductId_15  financial_services  ChannelId_3    500.0
# 17     ProviderId_6  ProductId_11        data_bundles  ChannelId_3   1000.0
# 18     ProviderId_4   ProductId_6  financial_services  ChannelId_2    -10.0
# 19     ProviderId_5   ProductId_3             airtime  ChannelId_3    500.0
# 20     ProviderId_4   ProductId_6  financial_services  ChannelId_2    -25.0
# 21     ProviderId_5   ProductId_3             airtime  ChannelId_3    500.0
# 22     ProviderId_4   ProductId_6  financial_services  ChannelId_2    -25.0
# 23     ProviderId_6   ProductId_3             airtime  ChannelId_3   1000.0
# 24     ProviderId_6  ProductId_10             airtime  ChannelId_3    500.0
# 25     ProviderId_4   ProductId_6  financial_services  ChannelId_2    -10.0
# 26     ProviderId_6   ProductId_3             airtime  ChannelId_3   1000.0
# 27     ProviderId_6  ProductId_19                  tv  ChannelId_3   3500.0
# 28     ProviderId_4   ProductId_6  financial_services  ChannelId_2    -70.0
# 29     ProviderId_5  ProductId_15  financial_services  ChannelId_3   2000.0
# ...             ...           ...                 ...          ...      ...
# 95632  ProviderId_6   ProductId_3             airtime  ChannelId_3   1000.0
# 95633  ProviderId_6  ProductId_10             airtime  ChannelId_3  15000.0
# 95634  ProviderId_5   ProductId_3             airtime  ChannelId_3   1000.0
# 95635  ProviderId_5  ProductId_10             airtime  ChannelId_3   1000.0
# 95636  ProviderId_4   ProductId_6  financial_services  ChannelId_2    -50.0
# 95637  ProviderId_4   ProductId_6  financial_services  ChannelId_2    -20.0
# 95638  ProviderId_6  ProductId_10             airtime  ChannelId_3  15000.0
# 95639  ProviderId_5  ProductId_15  financial_services  ChannelId_3   1000.0
# 95640  ProviderId_6  ProductId_10             airtime  ChannelId_3  15000.0
# 95641  ProviderId_6   ProductId_3             airtime  ChannelId_3   1000.0
# 95642  ProviderId_4   ProductId_6  financial_services  ChannelId_2    -50.0
# 95643  ProviderId_6  ProductId_10             airtime  ChannelId_3  15000.0
# 95644  ProviderId_6   ProductId_3             airtime  ChannelId_3   1200.0
# 95645  ProviderId_3   ProductId_1             airtime  ChannelId_3   5000.0
# 95646  ProviderId_4   ProductId_6  financial_services  ChannelId_2    -60.0
# 95647  ProviderId_4   ProductId_6  financial_services  ChannelId_2   -250.0
# 95648  ProviderId_1  ProductId_15  financial_services  ChannelId_3   2000.0
# 95649  ProviderId_1  ProductId_15  financial_services  ChannelId_3   3000.0
# 95650  ProviderId_1  ProductId_15  financial_services  ChannelId_3   2800.0
# 95651  ProviderId_6   ProductId_1             airtime  ChannelId_3   3000.0
# 95652  ProviderId_1  ProductId_15  financial_services  ChannelId_3   1700.0
# 95653  ProviderId_4   ProductId_6  financial_services  ChannelId_2   -140.0
# 95654  ProviderId_6   ProductId_1             airtime  ChannelId_3   1000.0
# 95655  ProviderId_4   ProductId_6  financial_services  ChannelId_2    -50.0
# 95656  ProviderId_6  ProductId_10             airtime  ChannelId_3  50000.0
# 95657  ProviderId_4   ProductId_6  financial_services  ChannelId_2  -1000.0
# 95658  ProviderId_6  ProductId_10             airtime  ChannelId_3   1000.0
# 95659  ProviderId_4   ProductId_6  financial_services  ChannelId_2    -20.0
# 95660  ProviderId_6  ProductId_19                  tv  ChannelId_3   3000.0
# 95661  ProviderId_4   ProductId_6  financial_services  ChannelId_2    -60.0
#
#          Value        Date      Time  PricingStrategy  FraudResult
# 0       1000.0  2018-11-15   2:18:49                2            0
# 1         20.0  2018-11-15   2:19:08                2            0
# 2        500.0  2018-11-15   2:44:21                2            0
# 3      20000.0  2018-11-15   3:32:55                2            0
# 4        644.0  2018-11-15   3:34:21                2            0
# 5       2000.0  2018-11-15   3:35:10                2            0
# 6      10000.0  2018-11-15   3:44:31                4            0
# 7        500.0  2018-11-15   3:45:13                2            0
# 8        500.0  2018-11-15   4:14:59                2            0
# 9        600.0  2018-11-15   4:31:48                2            0
# 10       890.0  2018-11-15   4:32:08                2            0
# 11        40.0  2018-11-15   4:32:42                2            0
# 12       600.0  2018-11-15   4:35:10                2            0
# 13      4000.0  2018-11-15   4:47:31                2            0
# 14      4000.0  2018-11-15   4:48:09                2            0
# 15      4000.0  2018-11-15   4:51:20                2            0
# 16       500.0  2018-11-15   4:52:37                2            0
# 17      1000.0  2018-11-15   4:54:00                2            0
# 18        10.0  2018-11-15   4:54:18                2            0
# 19       500.0  2018-11-15   4:56:25                4            0
# 20        25.0  2018-11-15   4:57:00                2            0
# 21       500.0  2018-11-15   4:59:02                4            0
# 22        25.0  2018-11-15   4:59:41                2            0
# 23      1000.0  2018-11-15   4:59:51                2            0
# 24       500.0  2018-11-15   5:06:25                2            0
# 25        10.0  2018-11-15   5:06:39                2            0
# 26      1000.0  2018-11-15   5:37:24                2            0
# 27      3500.0  2018-11-15   5:38:25                2            0
# 28        70.0  2018-11-15   5:38:35                2            0
# 29      2000.0  2018-11-15   5:38:37                2            0
# ...        ...         ...       ...              ...          ...
# 95632   1000.0  2019-02-13   9:30:56                2            0
# 95633  15000.0  2019-02-13   9:30:59                2            0
# 95634   1000.0  2019-02-13   9:33:17                4            0
# 95635   1000.0  2019-02-13   9:33:43                4            0
# 95636     50.0  2019-02-13   9:33:59                2            0
# 95637     20.0  2019-02-13   9:34:02                2            0
# 95638  15000.0  2019-02-13   9:34:44                2            0
# 95639   1000.0  2019-02-13   9:35:19                2            0
# 95640  15000.0  2019-02-13   9:36:07                2            0
# 95641   1000.0  2019-02-13   9:36:18                2            0
# 95642     50.0  2019-02-13   9:36:48                2            0
# 95643  15000.0  2019-02-13   9:37:48                2            0
# 95644   1200.0  2019-02-13   9:39:24                2            0
# 95645   5000.0  2019-02-13   9:39:30                1            0
# 95646     60.0  2019-02-13   9:40:03                2            0
# 95647    250.0  2019-02-13   9:40:18                2            0
# 95648   2000.0  2019-02-13   9:40:18                2            0
# 95649   3000.0  2019-02-13   9:45:44                2            0
# 95650   2800.0  2019-02-13   9:46:54                2            0
# 95651   3000.0  2019-02-13   9:50:12                2            0
# 95652   1700.0  2019-02-13   9:50:20                2            0
# 95653    140.0  2019-02-13   9:50:34                2            0
# 95654   1000.0  2019-02-13   9:52:31                2            0
# 95655     50.0  2019-02-13   9:52:49                2            0
# 95656  50000.0  2019-02-13   9:53:55                2            0
# 95657   1000.0  2019-02-13   9:54:09                2            0
# 95658   1000.0  2019-02-13   9:54:25                2            0
# 95659     20.0  2019-02-13   9:54:35                2            0
# 95660   3000.0  2019-02-13  10:01:10                2            0
# 95661     60.0  2019-02-13  10:01:28                2            0
#
# [95662 rows x 17 columns]

# %%
test.head()
# Out:
#          TransactionId         BatchId       AccountId       SubscriptionId  \
# 0  TransactionId_76871   BatchId_36123  AccountId_3957   SubscriptionId_887
# 1  TransactionId_73770   BatchId_15642  AccountId_4841  SubscriptionId_3829
# 2  TransactionId_26203   BatchId_53941  AccountId_4229   SubscriptionId_222
# 3    TransactionId_380  BatchId_102363   AccountId_648  SubscriptionId_2185
# 4  TransactionId_28195   BatchId_38780  AccountId_4841  SubscriptionId_3829
#
#         CustomerId CurrencyCode  CountryCode    ProviderId     ProductId  \
# 0  CustomerId_4406          UGX          256  ProviderId_6  ProductId_10
# 1  CustomerId_4406          UGX          256  ProviderId_4   ProductId_6
# 2  CustomerId_4683          UGX          256  ProviderId_6   ProductId_1
# 3   CustomerId_988          UGX          256  ProviderId_1  ProductId_21
# 4   CustomerId_988          UGX          256  ProviderId_4   ProductId_6
#
#       ProductCategory    ChannelId   Amount    Value        Date     Time  \
# 0             airtime  ChannelId_3   1000.0   1000.0  2018-11-15  2:18:49
# 1  financial_services  ChannelId_2    -20.0     20.0  2018-11-15  2:19:08
# 2             airtime  ChannelId_3    500.0    500.0  2018-11-15  2:44:21
# 3        utility_bill  ChannelId_3  20000.0  20000.0  2018-11-15  3:32:55
# 4  financial_services  ChannelId_2   -644.0    644.0  2018-11-15  3:34:21
#
#    PricingStrategy  FraudResult
# 0                2            0
# 1                2            0
# 2                2            0
# 3                2            0
# 4                2            0

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95662 entries, 0 to 95661
# Data columns (total 17 columns):
# TransactionId      95662 non-null object
# BatchId            95662 non-null object
# AccountId          95662 non-null object
# SubscriptionId     95662 non-null object
# CustomerId         95662 non-null object
# CurrencyCode       95662 non-null object
# CountryCode        95662 non-null int64
# ProviderId         95662 non-null object
# ProductId          95662 non-null object
# ProductCategory    95662 non-null object
# ChannelId          95662 non-null object
# Amount             95662 non-null float64
# Value              95662 non-null float64
# Date               95662 non-null object
# Time               95662 non-null object
# PricingStrategy    95662 non-null int64
# FraudResult        95662 non-null int64
# dtypes: float64(2), int64(3), object(12)
# memory usage: 12.4+ MB

# %%
test.isnull().values.any()
# Out:
# False

# %% [markdown]
# We can see from our dataset that we do not have any missing values

# %%
test.describe()
# Out:
#        CountryCode        Amount         Value  PricingStrategy   FraudResult
# count      95662.0  9.566200e+04  9.566200e+04     95662.000000  95662.000000
# mean         256.0  6.717846e+03  9.857110e+03         2.255974      0.002018
# std            0.0  1.233068e+05  1.230956e+05         0.732924      0.044872
# min          256.0 -1.000000e+06  1.200000e+00         0.000000      0.000000
# 25%          256.0 -5.000000e+01  2.750000e+02         2.000000      0.000000
# 50%          256.0  1.000000e+03  1.000000e+03         2.000000      0.000000
# 75%          256.0  2.800000e+03  5.000000e+03         2.000000      0.000000
# max          256.0  9.880000e+06  9.880000e+06         4.000000      1.000000

# %%
cat_cols = ['ProductId','ProductCategory',
            'ProviderId', 'ChannelId']
num_cols = ['Amount', 'FraudResult','PricingStrategy']

# %%
for col in cat_cols:
    fig = plt.figure(figsize=(7,6)) # define plot area
    ax = fig.gca() # define axis  
    
    counts = test[col].value_counts() # find the counts for each unique category
    counts.plot.bar(ax = ax) # Use the plot.bar method on the counts data frame
    ax.set_title('Bar plot for ' + col)

# %% [markdown]
# From our Barpots above:
#     1. We observe that Product_6, 3, 10 and 15 were purchased more than other products
#         -These were under the ProductCategory financial Services and airtime
#     2. In correlation to Statement 1, financial services and airtem have the highest count number in ProductCategory
#     3. From Plot 3, we see that provider_4 and Provider_6 had high counts due to their productCategory
#     4. ChannelId_3 was used for payments more than every other platform

# %%
for col in cat_cols:
    plt.figure(figsize = (12,5))
    sns.boxplot(col, 'Amount', data=test)
    plt.ticklabel_format(style='plain', axis='y')
    plt.xticks(rotation=90)
    plt.xlabel(col) # Set text for the x axis
    plt.ylabel('Amount')# Set text for y axis
    plt.show()

# %% [markdown]
# Looking at the boxplot between out categorical variables and amount:
#     1.Product_15 has more transaction with high Amount than any  other Value
#     2.From plot 2 we see that product_15 belongs to the financial services as their outliers are very similar
#     3. In Plot 3 while provider_1 and provider_6 are both involved in financial Services, we can see that
#     the value of transaction for provider 1 is much higher
#     4.From plot4 we observe that ChannelId_3 is used to make more credits transaction than any other channel
#     while ChannelId_2 is used for more debit transactions

# %%
corr = test.corr()
f,ax = plt.subplots(figsize=(8,8))
sns.heatmap(corr, square=True)

# %% [markdown]
# From our Heatmap, we can see that there is a high correlation between Amount and FraudResult

# %%
plt.figure(figsize = (20,8))
sns.relplot(x = 'ProductCategory', y = 'Amount', hue = 'FraudResult', data = test,height = 7,aspect = 2)
plt.ticklabel_format(style='plain', axis='y')
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8], <a list of 9 Text xticklabel objects>)

# %% [markdown]
# In order to understand the correlation of the heatmap, we plot our ProductCategory against Amount while
# bringing our FraudResult as hue
#
# We discover that there is high Fraud detection on the financial service product category. This could be as a result of
# high no of transactions that occur on this category.
#
# Also there is a fair amount of fraud detection on the airtime product catgegory . It is safe to say that categories
# with high transction have high chances of Fraud Ocurrence

# %% [markdown]
# ### Reccommendations and Conclusions
#
#
# Based on our discovery, Security measures should be put in place to check Fraud detection. Looking at our last plot, we see that as the the transactuon value increases, the fraudResult becomes more visible. THis could likely be due to forged figures or negilgence on the provider part to monitor transactions properly.
# Hence Policies should be put in place to help keep providers in check ensuring that fraud occurrence is to minimal when customers engage their products.

# %%
import pyodbc


# Connect to SQL Server
db_engine = pyodbc.connect("Driver={SQL Server Native Client 11.0};"

                      "Server=172.10.9.201\MSSQLSERVER2;"

                      "Database=DataAnalytics;"

                      "uid=datateam;"

                      "pwd=password;"
                      'Trusted_Connection=yes;')
cursor = db_engine.cursor()   
               
cursor.execute('CREATE TABLE test_data (TransactionId varchar(50),BatchId varchar(50),AccountId varchar(50),SubscriptionId  varchar(50),CustomerId varchar(50),CurrencyCode varchar(10),CountryCode  varchar(10),ProviderId   varchar(50),ProductId varchar(50),ProductCategory varchar(50), ChannelId  varchar(50),  Amount  money , Value   money ,      Date    date, Time Time , PricingStrategy   int ,FraudResult  smallint)')

# Insert DataFrame to Table
for row in df_test.itertuples():
    cursor.execute('''
                INSERT INTO DataAnalytics.dbo.test_data (TransactionId','BatchId','AccountId','SubscriptionId','CustomerId','CurrencyCode'
                                    ,'CountryCode','ProviderId','ProductId','ProductCategory','ChannelId','Amount','Value',
                                   'Date','Time','PricingStrategy','FraudResult)
                VALUES (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)
                ''',
                row.TransactionId, 
                row.BatchId,
                row.AccountId,
                row.SubscriptionId,
                row.CustomerId,
                row.CurrencyCode,
                row.CountryCode,
                row.ProviderId,
                row.ProductId,
                row.ProductCategory,
                row.ChannelId,
                row.Amount,
                row.Value,
                row.Date,
                row.Time,
                row.PricingStrategy,
                row.FraudResult,
                
                )
db_engine.commit()

# %%
import pyodbc


# Connect to SQL Server
db_engine = pyodbc.connect("Driver={SQL Server Native Client 11.0};"

                      "Server=GIFT-PC\MYSERVER;"

                      "Database=Sample;"

                      'Trusted_Connection=yes;')
cursor = db_engine.cursor()   
               
cursor.execute('CREATE TABLE test_data (TransactionId varchar(50),BatchId varchar(50),AccountId varchar(50),SubscriptionId  varchar(50),CustomerId varchar(50),CurrencyCode varchar(10),CountryCode  varchar(10),ProviderId   varchar(50),ProductId varchar(50),ProductCategory varchar(50), ChannelId  varchar(50), Amount  money , Value money , Date date, Time Time , PricingStrategy int ,FraudResult smallint)')

# Insert DataFrame to Table
for row in df_test.itertuples():
    cursor.execute('''
                INSERT INTO DataAnalytics.dbo.test_data (TransactionId','BatchId','AccountId','SubscriptionId','CustomerId','CurrencyCode'
                                    ,'CountryCode','ProviderId','ProductId','ProductCategory','ChannelId','Amount','Value',
                                   'Date','Time','PricingStrategy','FraudResult)
                VALUES (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)
                ''',
                row.TransactionId, 
                row.BatchId,
                row.AccountId,
                row.SubscriptionId,
                row.CustomerId,
                row.CurrencyCode,
                row.CountryCode,
                row.ProviderId,
                row.ProductId,
                row.ProductCategory,
                row.ChannelId,
                row.Amount,
                row.Value,
                row.Date,
                row.Time,
                row.PricingStrategy,
                row.FraudResult 
                )
db_engine.commit()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-21-aa5cdd221626> in <module>
#      38                 row.Time,
#      39                 row.PricingStrategy,
# ---> 40                 row.FraudResult
#      41                 )
#      42 db_engine.commit()
#
# ProgrammingError: ('42000', "[42000] [Microsoft][SQL Server Native Client 11.0][SQL Server]Incorrect syntax near ','. (102) (SQLExecDirectW); [42000] [Microsoft][SQL Server Native Client 11.0][SQL Server]Statement(s) could not be prepared. (8180)")

# %%
cursor = db_engine.cursor()   
               
cursor.execute('''
               CREATE TABLE test_data (TransactionId varchar(50),BatchId varchar(50),
               AccountId varchar(50),SubscriptionId  varchar(50),CustomerId varchar(50),CurrencyCode varchar(10),CountryCode  
               varchar(10),ProviderId   varchar(50),ProductId varchar(50),ProductCategory varchar(50), ChannelId  varchar(50),
               Amount  money , Value money , Date date, Time Time , PricingStrategy int ,FraudResult smallint)''')
db_engine.commit()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-20-e17aa05d7869> in <module>
#       5                AccountId varchar(50),SubscriptionId  varchar(50),CustomerId varchar(50),CurrencyCode varchar(10),CountryCode
#       6                varchar(10),ProviderId   varchar(50),ProductId varchar(50),ProductCategory varchar(50), ChannelId  varchar(50),
# ----> 7                Amount  money , Value money , Date date, Time Time , PricingStrategy int ,FraudResult smallint)''')
#       8 db_engine.commit()
#
# OperationalError: ('08S01', '[08S01] [Microsoft][SQL Server Native Client 11.0]Communication link failure (0) (SQLExecDirectW)')

# %%
db_engine = pyodbc.connect("Driver={SQL Server Native Client 11.0};"

                      "Server=GIFT-PC\MYSERVER;"

                      "Database=Sample;"

                      'Trusted_Connection=yes;')
